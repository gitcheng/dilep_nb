# %%
import matplotlib.pyplot as plt

# %%
x= np.arange(-0.003, 0.004, 0.001)
y= np.array([0.00745, 0.00545, 0.00345, 0.00145,-0.00055,-0.00255, -0.00455])
yerr= np.array([0.0008026, 0.000803, 0.000803, 0.000804, 0.000804, 0.000805, 0.000806])

# %%
plt.figure(figsize=(10,6))
plt.errorbar(x,y,yerr=yerr, fmt='o')
plt.xlabel(r'$a_{e1}$', fontsize='xx-large')
plt.ylabel(r'$A_{C\! P}$', fontsize='xx-large')
plt.grid(linestyle=':')

# %%
np.polyfit(x,y, 1)
# Out:
# array([ -2.00000000e+00,   1.45000000e-03])

# %%
params= np.polyfit(x,y,1)
p1d= np.poly1d([0,1.45e-3])
curve = p1d(x)
plt.errorbar(x,y,yerr=yerr)
plt.plot(x, curve, label=' Fit curve')
print params
# Out:
# [ -2.00000000e+00   1.45000000e-03]
