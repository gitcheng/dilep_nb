# %%
import numpy as np
import pylab as P

# %%
data1 = np.load('bootstrap-acp/acp-wmodel-fitnoweight/yieldfitcurve.npz')
data2 = np.load('bootstrap-acp/acp-noweight-self-ae1-1/yieldfitcurve.npz')
print data1.files
# Out:
# ['npee_bkg', 'pnee_all', 'nnee_offp', 'nnmm_all', 'npee_all', 'pnme_bkg', 'npem_offp', 'ppme_offp', 'nnem_bkg', 'nnmm_offp', 'npem_bkg', 'ppee_all', 'pnee_bkg', 'ppme_bkg', 'nnme_bkg', 'nnem_all', 'ppem_all', 'nnee_all', 'npme_bkg', 'ppmm_all', 'pnme_offp', 'pnem_bkg', 'nnme_all', 'npmm_offp', 'nnee_bkg', 'pnme_all', 'nnme_offp', 'npme_all', 'ppme_all', 'pnmm_all', 'ppee_bkg', 'ppee_offp', 'nnmm_bkg', 'npmm_bkg', 'pnmm_offp', 'pnmm_bkg', 'npee_offp', 'npmm_all', 'pnem_offp', 'npme_offp', 'npem_all', 'ppem_offp', 'pnee_offp', 'ppmm_bkg', 'ppmm_offp', 'pnem_all', 'nnem_offp', 'ppem_bkg']

# %%
d1=data1['nnem_all']
d1.dtype
# Out:
# dtype([('x', '<f4'), ('y', '<f4'), ('e', '<f4'), ('c', '<f4')])

# %%
d1= data1['nnem_all']
d2= data2['nnem_all']

P.figure(figsize=(10,6))
P.errorbar(d1['x'], d1['y']-d1['c'], yerr=d1['e'], fmt='o')
P.errorbar(d2['x'], d2['y']-d2['c'], yerr=d2['e'], fmt='o')
P.grid(linestyle=':')
