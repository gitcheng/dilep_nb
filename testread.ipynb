# %%
import numpy as np

# %%
# T was saved by :  np.save('testnpsave.npy',T)T = np.load('testnpsave.npy')

# %%
hexbin(T['p1cm'],T['p2cm'], gridsize=40)colorbar()
# Out:
# &lt;matplotlib.colorbar.Colorbar instance at 0x107f17ea8&gt;

# %%
# View the array as recarrayT = T.view(np.recarray)

# %%
hexbin(T.p1cm,T.p2cm, gridsize=40)colorbar()
# Out:
# &lt;matplotlib.colorbar.Colorbar instance at 0x10841d830&gt;
