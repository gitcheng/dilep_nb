# %%
import numpy as np
import pylab as P

# %%
a = np.load('ntuple/V4/sprvars-reduce/spr_pdg11/os-BBandOff-mm.npz')
data= a['arr_0']
data
# Out:
# array([ (-0.887617826461792, 1.944447636604309, 1.433210015296936, False, False, 3.872422456741333, -1, False, True, 6, False, False, 0.8752995133399963, 0.6251285672187805, True, False, 0.3462539613246918, 0.7982926964759827, 7.945787831513261, 0.05062111045298992),
#        (0.37597930431365967, -1.8989802598953247, 1.2172579765319824, False, False, 4.307864665985107, -1, False, True, 4, False, True, 2.18296480178833, 0.8088915348052979, False, False, 0.15330372750759125, 0.8709421157836914, 7.945787831513261, 0.3493499343071337),
#        (-0.408337265253067, -0.09881250560283661, 0.4904070198535919, False, False, -0.13427051901817322, -1, False, True, 4, False, False, 1.6447665691375732, 1.4384913444519043, True, False, 0.2535208761692047, 0.7941198945045471, 7.945787831513261, 0.1011208789569895),
#        ...,
# ...

# %%
evt0= data[data['evttype2']==0]
evt1= data[data['evttype2']==1]

# %%
fig= P.figure(figsize=(10,8))
h0= P.hist(evt0['spr'],bins=100,histtype='step')
h1= P.hist(evt1['spr'],bins=100,histtype='step')

# %%
print data.weight
# Out:
# <span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansigreen">/Users/chcheng/Work/dilepton/workdir/&lt;ipython-input-5-8bbcf035c4c0&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansired"> </span><span class="ansigreen">print</span> data<span class="ansiblue">.</span>weight<span class="ansiblue"></span>
#
# <span class="ansired">AttributeError</span>: &apos;numpy.ndarray&apos; object has no attribute &apos;weight&apos;
